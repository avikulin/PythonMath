# %% [markdown]
# # Sklearn

# %% [markdown]
# ## sklearn.grid_search

# %% [markdown]
# документация: http://scikit-learn.org/stable/modules/grid_search.html

# %%
from sklearn import model_selection, datasets, linear_model, metrics

import numpy as np
import pandas as pd

# %% [markdown]
# ### Генерация датасета

# %%
iris = datasets.load_iris()

# %%
train_data, test_data, train_labels, test_labels = model_selection.train_test_split(iris.data, iris.target, 
                                                                                     test_size = 0.3,random_state = 0)

# %% [markdown]
# ### Задание модели

# %%
classifier = linear_model.SGDClassifier(random_state = 0)

# %% [markdown]
# ### Генерация сетки

# %%
classifier.get_params().keys()
# Out:
# ['n_jobs',
#  'shuffle',
#  'verbose',
#  'class_weight',
#  'n_iter_no_change',
#  'fit_intercept',
#  'penalty',
#  'random_state',
#  'tol',
#  'epsilon',
#  'n_iter',
#  'validation_fraction',
#  'learning_rate',
#  'max_iter',
#  'alpha',
#  'early_stopping',
#  'warm_start',
#  'loss',
#  'eta0',
#  'l1_ratio',
#  'average',
#  'power_t']

# %%
parameters_grid = {
    'loss' : ['hinge', 'log', 'squared_hinge', 'squared_loss'],
    'penalty' : ['l1', 'l2'],
    'max_iter':np.linspace(1,1000,num=100),
    'tol':np.linspace(1e-5, 1e-3,num = 1e-4),
#     'n_iter' : range(5,10),
    'alpha' : np.linspace(0.0001, 0.001, num = 5),
}
# Out:
# C:\Users\avikulin\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
#   """

# %%
cv = model_selection.StratifiedShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Подбор параметров и оценка качества

# %% [markdown]
# #### Grid search

# %%
grid_cv = model_selection.GridSearchCV(classifier, parameters_grid, scoring = 'accuracy', cv = cv)

# %%
# %%time
grid_cv.fit(train_data, train_labels)

# %%
grid_cv.best_estimator_
# Out:
# SGDClassifier(alpha=0.0007750000000000001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='squared_hinge',
#        max_iter=939.4545454545455, n_iter=None, n_iter_no_change=5,
#        n_jobs=None, penalty='l1', power_t=0.5, random_state=0,
#        shuffle=True, tol=None, validation_fraction=0.1, verbose=0,
#        warm_start=False)

# %%
print grid_cv.best_score_
print grid_cv.best_params_
# Out:
# 0.9952380952380953
# {'penalty': 'l1', 'alpha': 0.0007750000000000001, 'max_iter': 939.4545454545455, 'loss': 'squared_hinge'}

# %%
grid_cv.cv_results_ 
# .grid_scores_[:10]
# Out:
# {'mean_fit_time': array([0.00060003, 0.0007    , 0.00059998, ..., 0.00900004, 0.01109998,
#         0.00829995]),
#  'mean_score_time': array([1.99985504e-04, 9.99927521e-05, 2.00009346e-04, ...,
#         0.00000000e+00, 9.99927521e-05, 3.00025940e-04]),
#  'mean_test_score': array([0.5952381 , 0.58095238, 0.76190476, ..., 0.32857143, 0.34761905,
#         0.27619048]),
#  'mean_train_score': array([0.58452381, 0.58214286, 0.75714286, ..., 0.31547619, 0.3452381 ,
#         0.29047619]),
#  'param_alpha': masked_array(data=[0.0001, 0.0001, 0.0001, ..., 0.001, 0.001, 0.001],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param

#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 717.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 717.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 727.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 727.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 737.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 737.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 747.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 747.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 757.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 757.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 767.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 767.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 778.0000000000001,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 778.0000000000001,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 788.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 788.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 798.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 798.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 808.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 808.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 818.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 818.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 828.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 828.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 838.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 838.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 848.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 848.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 858.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 858.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 868.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 868.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 878.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 878.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 889.0000000000001,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 889.0000000000001,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 899.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 899.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 909.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 909.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 919.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 919.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 929.3636363636365,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 929.3636363636365,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 939.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 939.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 949.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 949.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 959.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 959.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 969.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 969.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 979.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 979.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 989.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'log',
#    'max_iter': 989.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001, 'loss': 'log', 'max_iter': 1000.0, 'penalty': 'l1'},
#   {'alpha': 0.0001, 'loss': 'log', 'max_iter': 1000.0, 'penalty': 'l2'},
#   {'alpha': 0.0001, 'loss': 'squared_hinge', 'max_iter': 1.0, 'penalty': 'l1'},
#   {'alpha': 0.0001, 'loss': 'squared_hinge', 'max_iter': 1.0, 'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 11.090909090909092,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 11.090909090909092,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 21.181818181818183,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 21.181818181818183,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 31.272727272727273,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 31.272727272727273,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 41.36363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 41.36363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 51.45454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 51.45454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 61.54545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 61.54545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 71.63636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 71.63636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 81.72727272727273,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 81.72727272727273,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 91.81818181818183,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 91.81818181818183,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 101.90909090909092,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 101.90909090909092,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 112.00000000000001,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 112.00000000000001,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 122.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 122.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 132.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 132.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 142.27272727272728,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 142.27272727272728,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 152.36363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 152.36363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 162.45454545454547,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 162.45454545454547,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 172.54545454545456,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 172.54545454545456,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 182.63636363636365,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 182.63636363636365,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 192.72727272727275,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 192.72727272727275,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 202.81818181818184,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 202.81818181818184,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 212.90909090909093,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 212.90909090909093,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 223.00000000000003,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 223.00000000000003,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 233.09090909090912,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 233.09090909090912,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 243.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 243.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 253.27272727272728,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 253.27272727272728,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 263.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 263.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 273.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 273.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 283.54545454545456,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 283.54545454545456,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 293.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 293.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 303.72727272727275,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 303.72727272727275,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 313.81818181818187,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 313.81818181818187,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 323.90909090909093,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 323.90909090909093,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 334.0,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 334.0,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 344.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 344.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 354.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 354.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 364.2727272727273,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 364.2727272727273,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 374.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 374.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 384.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 384.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 394.54545454545456,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 394.54545454545456,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 404.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 404.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 414.72727272727275,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 414.72727272727275,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 424.81818181818187,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 424.81818181818187,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 434.90909090909093,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 434.90909090909093,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 445.00000000000006,
#    'penalty': 'l1'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
#    'max_iter': 445.00000000000006,
#    'penalty': 'l2'},
#   {'alpha': 0.0001,
#    'loss': 'squared_hinge',
# ...
#    'loss': 'hinge',
#    'max_iter': 313.81818181818187,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 323.90909090909093,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 323.90909090909093,
#    'penalty': 'l2'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 334.0, 'penalty': 'l1'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 334.0, 'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 344.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 344.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 354.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 354.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 364.2727272727273,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 364.2727272727273,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 374.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 374.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 384.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 384.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 394.54545454545456,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 394.54545454545456,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 404.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 404.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 414.72727272727275,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 414.72727272727275,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 424.81818181818187,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 424.81818181818187,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 434.90909090909093,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 434.90909090909093,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 445.00000000000006,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 445.00000000000006,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 455.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 455.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 465.18181818181824,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 465.18181818181824,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 475.2727272727273,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 475.2727272727273,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 485.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 485.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 495.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 495.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 505.54545454545456,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 505.54545454545456,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 515.6363636363636,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 515.6363636363636,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 525.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 525.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 535.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 535.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 545.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 545.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 556.0, 'penalty': 'l1'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 556.0, 'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 566.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 566.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 576.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 576.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 586.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 586.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 596.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 596.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 606.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 606.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 616.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 616.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 626.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 626.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 636.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 636.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 646.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 646.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 656.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 656.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 667.0, 'penalty': 'l1'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 667.0, 'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 677.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 677.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 687.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 687.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 697.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 697.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 707.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 707.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 717.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 717.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 727.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 727.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 737.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 737.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 747.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 747.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 757.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 757.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 767.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 767.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 778.0000000000001,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 778.0000000000001,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 788.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 788.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 798.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 798.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 808.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 808.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 818.3636363636364,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 818.3636363636364,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 828.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 828.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 838.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 838.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 848.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 848.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 858.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 858.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 868.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 868.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 878.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 878.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 889.0000000000001,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 889.0000000000001,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 899.0909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 899.0909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 909.1818181818182,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 909.1818181818182,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 919.2727272727274,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 919.2727272727274,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 929.3636363636365,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 929.3636363636365,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 939.4545454545455,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 939.4545454545455,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 949.5454545454546,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 949.5454545454546,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 959.6363636363637,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 959.6363636363637,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 969.7272727272727,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 969.7272727272727,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 979.8181818181819,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 979.8181818181819,
#    'penalty': 'l2'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 989.909090909091,
#    'penalty': 'l1'},
#   {'alpha': 0.000325,
#    'loss': 'hinge',
#    'max_iter': 989.909090909091,
#    'penalty': 'l2'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 1000.0, 'penalty': 'l1'},
#   {'alpha': 0.000325, 'loss': 'hinge', 'max_iter': 1000.0, 'penalty': 'l2'},
#   ...],
#  'rank_test_score': array([2986, 2992, 2924, ..., 3529, 3312, 3926]),
#  'split0_test_score': array([0.71428571, 0.71428571, 0.33333333, ..., 0.33333333, 0.61904762,
#         0.0952381 ]),
#  'split0_train_score': array([0.69047619, 0.69047619, 0.41666667, ..., 0.4047619 , 0.44047619,
#         0.25      ]),
#  'split1_test_score': array([0.33333333, 0.28571429, 0.66666667, ..., 0.33333333, 0.23809524,
#         0.38095238]),
#  'split1_train_score': array([0.3452381 , 0.32142857, 0.69047619, ..., 0.32142857, 0.25      ,
#         0.36904762]),
#  'split2_test_score': array([0.71428571, 0.71428571, 0.85714286, ..., 0.38095238, 0.38095238,
#         0.38095238]),
#  'split2_train_score': array([0.69047619, 0.69047619, 0.76190476, ..., 0.35714286, 0.36904762,
#         0.39285714]),
#  'split3_test_score': array([0.80952381, 0.42857143, 1.        , ..., 0.33333333, 0.28571429,
#         0.33333333]),
#  'split3_train_score': array([0.78571429, 0.47619048, 0.91666667, ..., 0.29761905, 0.41666667,
#         0.22619048]),
#  'split4_test_score': array([0.71428571, 0.71428571, 0.85714286, ..., 0.28571429, 0.23809524,
#         0.28571429]),
#  'split4_train_score': array([0.69047619, 0.69047619, 0.86904762, ..., 0.39285714, 0.32142857,
#         0.4047619 ]),
#  'split5_test_score': array([0.61904762, 0.61904762, 0.71428571, ..., 0.19047619, 0.23809524,
#         0.19047619]),
#  'split5_train_score': array([0.63095238, 0.63095238, 0.69047619, ..., 0.30952381, 0.23809524,
#         0.25      ]),
#  'split6_test_score': array([0.71428571, 0.71428571, 0.61904762, ..., 0.38095238, 0.38095238,
#         0.33333333]),
#  'split6_train_score': array([0.69047619, 0.69047619, 0.64285714, ..., 0.29761905, 0.36904762,
#         0.22619048]),
#  'split7_test_score': array([0.33333333, 0.61904762, 0.9047619 , ..., 0.33333333, 0.42857143,
#         0.23809524]),
#  'split7_train_score': array([0.32142857, 0.63095238, 0.91666667, ..., 0.23809524, 0.4047619 ,
#         0.22619048]),
#  'split8_test_score': array([0.28571429, 0.28571429, 0.95238095, ..., 0.33333333, 0.38095238,
#         0.23809524]),
#  'split8_train_score': array([0.30952381, 0.30952381, 0.97619048, ..., 0.27380952, 0.35714286,
#         0.27380952]),
#  'split9_test_score': array([0.71428571, 0.71428571, 0.71428571, ..., 0.38095238, 0.28571429,
#         0.28571429]),
#  'split9_train_score': array([0.69047619, 0.69047619, 0.69047619, ..., 0.26190476, 0.28571429,
#         0.28571429]),
#  'std_fit_time': array([4.89920850e-04, 4.58255581e-04, 4.89881913e-04, ...,
#         7.15255737e-08, 2.99954433e-04, 4.58281595e-04]),
#  'std_score_time': array([0.00039997, 0.00029998, 0.00040002, ..., 0.        , 0.00029998,
#         0.0004583 ]),
#  'std_test_score': array([0.18717375, 0.17010068, 0.18687064, ..., 0.05408484, 0.1127878 ,
#         0.08464947]),
#  'std_train_score': array([0.17345446, 0.14729708, 0.15929265, ..., 0.05195989, 0.06606875,
#         0.06759557])}

# %% [markdown]
# #### Randomized grid search

# %%
randomized_grid_cv = model_selection.RandomizedSearchCV(classifier, parameters_grid, scoring = 'accuracy', cv = cv, n_iter = 20, 
                                                   random_state = 0)

# %%
# %%time
randomized_grid_cv.fit(train_data, train_labels)
# Out:
# Wall time: 1.42 s
# RandomizedSearchCV(cv=StratifiedShuffleSplit(n_splits=10, random_state=0, test_size=0.2,
#             train_size=None),
#           error_score='raise-deprecating',
#           estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=0, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False),
#           fit_params=None, iid='warn', n_iter=20, n_jobs=None,
#           param_distributions={'penalty': ['l1', 'l2'], 'loss': ['hinge', 'log', 'squared_hinge', 'squared_loss'], 'max_iter': array([   1.     ,   11.09091, ...,  989.90909, 1000.     ]), 'alpha': array([0.0001 , 0.00032, 0.00055, 0.00078, 0.001  ])},
#           pre_dispatch='2*n_jobs', random_state=0, refit=True,
#           return_train_score='warn', scoring='accuracy', verbose=0)

# %%
print randomized_grid_cv.best_score_
print randomized_grid_cv.best_params_
# Out:
# 0.9857142857142858
# {'penalty': 'l1', 'loss': 'log', 'max_iter': 243.1818181818182, 'alpha': 0.0007750000000000001}
