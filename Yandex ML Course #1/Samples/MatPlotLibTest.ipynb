# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
from scipy import interpolate
import numpy as npabs

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
x = np.arange(-10,10,0.1)
y = x**3
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,10,2)
y = np.exp(-x/3.0) + np.random.randn(len(x))*0.05

print "x - ", x[0:5]
print "y - ", y[0:5]
# Out:
# x -  [0 2 4 6 8]
# y -  [1.03177703 0.5272657  0.25527258 0.06156513 0.07892054]

# %%
f = interpolate.interp1d(x,y, kind="quadratic")
x_new = np.arange(0,8,0.1)
y_new = f(x_new)

print "x (new) - ", x_new[0:5]
print "y (new) - ", y_new[0:5]

plt.plot(x,y,'o', x_new, y_new, '-')
plt.show()
# Out:
# x (new) -  [0.  0.1 0.2 0.3 0.4]
# y (new) -  [1.03177703 1.00031111 0.96950207 0.93934991 0.90985462]
